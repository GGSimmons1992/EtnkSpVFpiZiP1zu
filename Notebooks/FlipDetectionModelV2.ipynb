# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow.keras as keras
import keras.backend as K
from keras.optimizers import Adam
import os
from IPython.display import display
import util
# %autosave 5
# Out:
# Autosaving every 5 seconds
# Autosaving every 5 seconds

# %%
possibleConvFilters = util.createRangeFromMidpoint(37,40)

possibleConvAndPoolLayers = util.createRangeFromMidpoint(5,5)

possibleNumberOfFCLayers = util.createRangeFromMidpoint(17,17)
possibleNumberOfNeuronsPerFCLayer = util.createRangeFromMidpoint(17,20)

possibleNumberOfEpochs = util.createRangeFromMidpoint(27,28)

lastBestDropoutRate = 0.893147
lastBestAdamLearningRate = 0.000555
lastBestL2 = 143.215169

trial = 0

# %%
train = util.loadData("training")
dev,test = util.loadData("testing",.5)

choose = np.random.choice

n_convFilters = []
n_convAndPoolLayers = []
n_FCLayers = []
n_NeuronsPerFCLayers = []
n_Epochs = []
dropoutRates = []
adamLearningRates = []
L2Rates = []
trainScores = []
devScores = []

lastTrialForNotebook = trial + 10

while trial < lastTrialForNotebook:
    convFilters = choose(possibleConvFilters)

    convAndPoolLayers = choose(possibleConvAndPoolLayers)
    convAndPoolLayers = min([convAndPoolLayers,6])

    numberOfFCLayers = choose(possibleNumberOfFCLayers)
    numberOfNeuronsPerFCLayer = choose(possibleNumberOfNeuronsPerFCLayer)

    numberOfEpochs = choose(possibleNumberOfEpochs)
    
    dropoutRate = (np.random.rand() + lastBestDropoutRate)/2
    adamLearningRate = util.generateAdamLearningRate(lastBestAdamLearningRate)
    L2Rate = util.generateL2(lastBestL2)
    

    model = util.createModel(convFilters, convAndPoolLayers,numberOfFCLayers, numberOfNeuronsPerFCLayer, dropoutRate, adamLearningRate, L2Rate)

    model.fit(train,epochs=numberOfEpochs,verbose=0)

    model_path = f'../Models/FlipDetectionModelTrials/fd_model_{trial}.h5'
    model.save(model_path)
    model_size = os.path.getsize(model_path) / (1024 * 1024)
    if model_size < 40:
        print()
        print('trainScore')
        trainScore = model.evaluate(train)[1]
        print('devScore')
        devScore = model.evaluate(dev)[1]

        n_convFilters.append(convFilters)
        n_convAndPoolLayers.append(convAndPoolLayers)
        n_FCLayers.append(numberOfFCLayers)
        n_NeuronsPerFCLayers.append(numberOfNeuronsPerFCLayer)
        n_Epochs.append(numberOfEpochs)
        adamLearningRates.append(adamLearningRate)
        dropoutRates.append(dropoutRate)
        L2Rates.append(L2Rate)
        trainScores.append(trainScore)
        devScores.append(devScore)
        
        print('concluding trial ',trial)
        trial += 1
    else:
        print(f'redoing trial {trial}. Model was {model_size}MB.')
        failedTrial = util.createModelParametersDF([convFilters],[convAndPoolLayers],
                                              [numberOfFCLayers],[numberOfNeuronsPerFCLayer],[numberOfEpochs],
                                              [dropoutRate],[adamLearningRate],[L2Rate],[np.nan],[np.nan])
        display(failedTrial)
        
modelParametersDF = util.createModelParametersDF(n_convFilters,n_convAndPoolLayers,
                                            n_FCLayers,n_NeuronsPerFCLayers,n_Epochs,
                                            dropoutRates,adamLearningRates,L2Rates,trainScores,devScores)
display(modelParametersDF.sort_values(by='trainScore', ascending=False))
# Out:
# In non split
# Found 2392 files belonging to 2 classes.
# In split
# Found 597 files belonging to 2 classes.
# Using 299 files for training.
# Using 298 files for validation.
# 2024-06-16 18:02:36.940791: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [2392]
# 	 [[{{node Placeholder/_4}}]]
# 2024-06-16 18:02:36.940941: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [2392]
# 	 [[{{node Placeholder/_4}}]]
# 2024-06-16 18:02:37.643318: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# trainScore
# 75/75 [==============================] - 12s 146ms/step - loss: 0.3499 - f1_score: 0.6501
# devScore
# 2024-06-16 18:10:52.357246: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [299]
# 	 [[{{node Placeholder/_0}}]]
# 2024-06-16 18:10:52.357412: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [299]
# 	 [[{{node Placeholder/_0}}]]
# 10/10 [==============================] - 1s 96ms/step - loss: 0.3658 - f1_score: 0.6277
# concluding trial  0
#
# trainScore
# 75/75 [==============================] - 10s 127ms/step - loss: 0.4809 - f1_score: 0.6486
# devScore
# 10/10 [==============================] - 1s 80ms/step - loss: 0.4986 - f1_score: 0.6244
# concluding trial  1
#
# trainScore
# 75/75 [==============================] - 15s 196ms/step - loss: 0.3520 - f1_score: 0.6481
# devScore
# 10/10 [==============================] - 4s 412ms/step - loss: 0.3664 - f1_score: 0.6384
# concluding trial  2
#
# trainScore
# 75/75 [==============================] - 9s 115ms/step - loss: 21.6302 - f1_score: 0.6496
# devScore
# 10/10 [==============================] - 1s 78ms/step - loss: 21.6542 - f1_score: 0.6196
# concluding trial  3
#
# trainScore
# 75/75 [==============================] - 15s 191ms/step - loss: 0.3561 - f1_score: 0.6489
# devScore
# 10/10 [==============================] - 2s 115ms/step - loss: 0.3729 - f1_score: 0.6320
# concluding trial  4
#
# trainScore
# 75/75 [==============================] - 13s 163ms/step - loss: 0.3510 - f1_score: 0.6489
# devScore
# 10/10 [==============================] - 2s 101ms/step - loss: 0.3643 - f1_score: 0.6451
# concluding trial  5
#
# trainScore
# 75/75 [==============================] - 17s 219ms/step - loss: 0.3815 - f1_score: 0.6497
# devScore
# 10/10 [==============================] - 2s 172ms/step - loss: 0.3970 - f1_score: 0.6385
# concluding trial  6
#
# trainScore
# 75/75 [==============================] - 15s 159ms/step - loss: 0.3507 - f1_score: 0.6495
# devScore
# 10/10 [==============================] - 2s 111ms/step - loss: 0.3674 - f1_score: 0.6376
# concluding trial  7
#
# trainScore
# 75/75 [==============================] - 13s 166ms/step - loss: 0.3494 - f1_score: 0.6504
# devScore
# 10/10 [==============================] - 2s 118ms/step - loss: 0.3667 - f1_score: 0.6508
# concluding trial  8
#
# trainScore
# 75/75 [==============================] - 16s 210ms/step - loss: 0.3557 - f1_score: 0.6480
# devScore
# 10/10 [==============================] - 2s 160ms/step - loss: 0.3717 - f1_score: 0.6460
# concluding trial  9
#    n_convFilters  n_convAndPoolLayers  n_FCLayers  n_NeuronsPerFCLayers  \
# 8             38                    5          22                     9
# 0             30                    5          18                    22
# 6             54                    5          23                    11
# 3             22                    6          23                    12
# 7             34                    5          10                    26
# 5             31                    6          18                     7
# 4             52                    3          12                    14
# 1             36                    5           9                     8
# 2             46                    5          16                    13
# 9             50                    6          11                    13
#
#    n_Epochs  dropoutRate  adamLearningRates     L2Rates  trainScore  devScore
# 8        40     0.710042           0.000350   71.708797    0.650445  0.650836
# 0        17     0.639992           0.001957   72.133370    0.650066  0.627677
# 6        19     0.494695           0.000663  172.942159    0.649749  0.638469
# 3        13     0.761227           0.000377  445.776213    0.649564  0.619625
# 7        35     0.917976           0.004250  449.877265    0.649470  0.637643
# 5        29     0.549979           0.000394  493.901915    0.648901  0.645058
# 4        27     0.624219           0.001803   87.286954    0.648898  0.631977
# 1        19     0.781600           0.002559  157.720323    0.648561  0.624442
# 2        35     0.583768           0.000375  112.000875    0.648086  0.638418
# 9        18     0.739569           0.000396   71.724565    0.647965  0.645991
